# %% [markdown]
# # Opinion Review 데이터 세트를 이용한 문서 군집화 수행

# %%
import pandas as pd
import glob, os
path=r'C:\Users\204\Python\03_MachineLearning\05_군집\OpinosisDataset1.0\topics'
all_files = glob.glob(os.path.join(path, "*.data"))
print(all_files)
# Out:
# ['C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\accuracy_garmin_nuvi_255W_gps.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\bathroom_bestwestern_hotel_sfo.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\battery-life_amazon_kindle.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\battery-life_ipod_nano_8gb.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\battery-life_netbook_1005ha.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\buttons_amazon_kindle.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\comfort_honda_accord_2008.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\comfort_toyota_camry_2007.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\directions_garmin_nuvi_255W_gps.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\display_garmin_nuvi_255W_gps.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\eyesight-issues_amazon_kindle.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\features_windows7.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\fonts_amazon_kindle.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\food_holiday_inn_london.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\food_swissotel_chicago.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\free_bestwestern_hotel_sfo.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\gas_mileage_toyota_camry_2007.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\interior_honda_accord_2008.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\interior_toyota_camry_2007.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\keyboard_netbook_1005ha.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\location_bestwestern_hotel_sfo.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\location_holiday_inn_london.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\mileage_honda_accord_2008.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\navigation_amazon_kindle.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\parking_bestwestern_hotel_sfo.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\performance_honda_accord_2008.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\performance_netbook_1005ha.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\price_amazon_kindle.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\price_holiday_inn_london.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\quality_toyota_camry_2007.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\rooms_bestwestern_hotel_sfo.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\rooms_swissotel_chicago.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\room_holiday_inn_london.txt.data', 'C:\\Users\\204\\Python\\03_MachineLearning\\05_군집\\OpinosisDataset1.0\\topics\\satellite_garmin_nuvi_255W_gps.txt.data', 'C ...

# %%
filename_list = [] # 파일명들이 저장될 리스트
opinion_text = [] # 파일의 내용(주제)등이 저장될 리스트

# %% [markdown]
# 1. 개별 파일명들을 filename_list에 저장합니다
# 2. 개별파일의 내용은 Dataframe 로딩 후 다시 string으로 변환하여 opinion_text 리스트에 저장합니다

# %%
# 모든 파일네임으로 반복실행
for file_ in all_files:
    # 개별파일을 읽어서 DataFrame으로 생성
    df = pd.read_table(file_, index_col=None, header=0, encoding='latin1')
    
    # 전체경로에서 파일명(XXX.data)만 추출
    filename_ = file_.split('\\')[-1]
    # 추출한 파일명에서 .data를 제외한 나머지 이름 추출
    filename = filename_.split('.')[0]
    # 추출한 파일명은 파일명 리스트에 append
    filename_list.append(filename)
    # 파일의 내용은 opinion_text 리스트에 String 형식으로 변환하여 append
    opinion_text.append(df.to_string())

# 취합된 파일명과 파일 내용을 각각에 컬럼으로 담은 데이터 프레임 생성
document_df = pd.DataFrame({'filename':filename_list, 'opinion_text':opinion_text})
document_df.head()
# Out:
#                          filename  \
# 0   accuracy_garmin_nuvi_255W_gps
# 1  bathroom_bestwestern_hotel_sfo
# 2      battery-life_amazon_kindle
# 3      battery-life_ipod_nano_8gb
# 4     battery-life_netbook_1005ha
#
#                                         opinion_text
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...

# %% [markdown]
# ## Lemmatization을 위한 함수 생성

# %%
from nltk.stem import WordNetLemmatizer
import nltk
import string

# %%
# 특수기호의 아스키 코드값(key)과 None(value)이 조합된 딕셔너리 생성
remove_punct_dict = dict( ( ord(punct), None) for punct in string.punctuation)
# 어근 추출을 위한 객체 생성
lemmar = WordNetLemmatizer()

# %%
# 1. 전달인수로 전달된 text를 워드토큰화
# 2. 소문자로 모두 변환
# 3. remove_punct_dict에 들어있는 key값을 찾아서 value로 대체
# 4. 결과가 리턴되기 전 LemToken 함수 호출해서 결과를 받고 리턴함
def LemNormalize(text):
    text_1 = text.lower() # 소문자 변환
    text_2 = text_1.translate(remove_punct_dict) # 특수문자를 None으로 변환
    text_3 = nltk.word_tokenize(text_2) # 단어별로 분할
    text_4 = LemTokens(text_3) # Lemtokens 함수에 적용 호출
    return text_4 # 결과 리턴
    # return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))

# 위에서 전달된 tokens(분리되고 특수기호 없앤 단어들의 어근을 추출해서 리턴)
def LemTokens(tokens):
    result = []
    for token in tokens :
        k = lemmar.lemmatize(token) # 단어의 원형으로 변환
        result.append(k) # 원형으로 변형된 단어를 리스트에 추가
    return result
    # return [lemmar.lemmatize(token) for token in tokens]
# LemNormalize(document_df['opinion_text'][0])

# %% [markdown]
# ## TF-IDF 피처 벡터화, TfidVectorizer에서 피처 벡터화 수행 시 Lemmatization을 적용하여 토큰화 된 데이터를 TfidfVectorizer 객체의 fit_transform 데이터로 제공합니다

# %% [markdown]
# * LemNormalize 함수를 적용한 객체 생성
# * 생성된 객체로 fit와 transform 실행

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings
warnings.filterwarnings('ignore')

tfidf_vect = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english', \
                            ngram_range=(1,2), min_df=0.05, max_df=0.85)
# opinion_text 컬럼값으로 feature vectorzation 수행
feature_vect = tfidf_vect.fit_transform(document_df['opinion_text'])
# fit 대상과 transform 대상이 같다면 위와 같이 한 번에 실행할 수 있습니다

# %% [markdown]
# ## 군집 알고리즘(K-Mean)
# * 대표적인 비지도 학습 알고리즘입니다
# * 지도학습과 비지도 학습의 외형상 차이점은 target의 유무로 구분합니다
# * train feature 데이터와 train target 데이터로 학습하여 완성된 머신러닝 모델을 얻은후에, test feature로 테스트하고 결과를 test target과 비교하여 성능평가를 하는 지도학습의 모습과는 달리,
# * 비지도학습은 target 없이 feature들로만 학습하고 그 결과로 군집된 데이터결과(집단의 이름-label)와 완성된 머신러닝 모델을 얻습닌다

# %% [markdown]
# ### 5개의 군집으로 K-Means 군집

# %%
from sklearn.cluster import KMeans
# 5개의 집합으로 군집화 객체 생성 및 수행
# max_iter=10000   군집 알고리즙의 실행횟수 : 10000회
# n_clusters : 군집 단위 갯수
km_cluster = KMeans(n_clusters=5, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
# Out:
# KMeans(max_iter=10000, n_clusters=5, random_state=0)

# %%
# 군집 결과 타겟들(0,1,2,3,4)
cluster_label = km_cluster.labels_
# km_cluster.cluster_centers_ : 군집 중심점과의 거리들
cluster_centers = km_cluster.cluster_centers_
document_df['cluster_label'] = cluster_label
document_df.head()
# Out:
#                          filename  \
# 0   accuracy_garmin_nuvi_255W_gps
# 1  bathroom_bestwestern_hotel_sfo
# 2      battery-life_amazon_kindle
# 3      battery-life_ipod_nano_8gb
# 4     battery-life_netbook_1005ha
#
#                                         opinion_text  cluster_label
# 0                                                ...              0
# 1                                                ...              2
# 2                                                ...              4
# 3                                                ...              4
# 4                                                ...              4

# %%
document_df[ document_df['cluster_label']==0 ].sort_values(by='filename')
# Out:
#                             filename  \
# 0      accuracy_garmin_nuvi_255W_gps
# 51     accuracy_garmin_nuvi_255W_gps
# 8    directions_garmin_nuvi_255W_gps
# 59   directions_garmin_nuvi_255W_gps
# 33    satellite_garmin_nuvi_255W_gps
# 84    satellite_garmin_nuvi_255W_gps
# 34       screen_garmin_nuvi_255W_gps
# 85       screen_garmin_nuvi_255W_gps
# 48      updates_garmin_nuvi_255W_gps
# 99      updates_garmin_nuvi_255W_gps
# 50        voice_garmin_nuvi_255W_gps
# 101       voice_garmin_nuvi_255W_gps
#
#                                           opinion_text  cluster_label
# 0                                                  ...              0
# 51                                                 ...              0
# 8                                                  ...              0
# 59                                                 ...              0
# 33                                                 ...              0
# 84                                                 ...              0
# 34                                                 ...              0
# 85                                                 ...              0
# 48                                                 ...              0
# 99                                                 ...              0
# 50                                                 ...              0
# 101                                                ...              0

# %%
document_df[ document_df['cluster_label']==1 ].sort_values(by='filename')
# Out:
#                          filename  \
# 5           buttons_amazon_kindle
# 56          buttons_amazon_kindle
# 9    display_garmin_nuvi_255W_gps
# 60   display_garmin_nuvi_255W_gps
# 10  eyesight-issues_amazon_kindle
# 61  eyesight-issues_amazon_kindle
# 11              features_windows7
# 62              features_windows7
# 12            fonts_amazon_kindle
# 63            fonts_amazon_kindle
# 23       navigation_amazon_kindle
# 74       navigation_amazon_kindle
# 27            price_amazon_kindle
# 78            price_amazon_kindle
# 43     speed_garmin_nuvi_255W_gps
# 94     speed_garmin_nuvi_255W_gps
# 44                 speed_windows7
# 95                 speed_windows7
#
#                                          opinion_text  cluster_label
# 5                                                 ...              1
# 56                                                ...              1
# 9                                                 ...              1
# 60                                                ...              1
# 10                                                ...              1
# 61                                                ...              1
# 11                                                ...              1
# 62                                                ...              1
# 12                                                ...              1
# 63                                                ...              1
# 23                                                ...              1
# 74                                                ...              1
# 27                                                ...              1
# 78                                                ...              1
# 43                                                ...              1
# 94                                                ...              1
# 44                                                ...              1
# 95                                                ...              1

# %%
document_df[ document_df['cluster_label']==2 ].sort_values(by='filename')
# Out:
#                            filename  \
# 1    bathroom_bestwestern_hotel_sfo
# 52   bathroom_bestwestern_hotel_sfo
# 13          food_holiday_inn_london
# 64          food_holiday_inn_london
# 14           food_swissotel_chicago
# 65           food_swissotel_chicago
# 66       free_bestwestern_hotel_sfo
# 15       free_bestwestern_hotel_sfo
# 71   location_bestwestern_hotel_sfo
# 20   location_bestwestern_hotel_sfo
# 21      location_holiday_inn_london
# 72      location_holiday_inn_london
# 75    parking_bestwestern_hotel_sfo
# 24    parking_bestwestern_hotel_sfo
# 28         price_holiday_inn_london
# 79         price_holiday_inn_london
# 32          room_holiday_inn_london
# 83          room_holiday_inn_london
# 30      rooms_bestwestern_hotel_sfo
# 81      rooms_bestwestern_hotel_sfo
# 82          rooms_swissotel_chicago
# 31          rooms_swissotel_chicago
# 89    service_bestwestern_hotel_sfo
# 38    service_bestwestern_hotel_sfo
# 90       service_holiday_inn_london
# 39       service_holiday_inn_london
# 91  service_swissotel_hotel_chicago
# 40  service_swissotel_hotel_chicago
# 96      staff_bestwestern_hotel_sfo
# 45      staff_bestwestern_hotel_sfo
# 46          staff_swissotel_chicago
# 97          staff_swissotel_chicago
#
#                                          opinion_text  cluster_label
# 1                                                 ...              2
# 52                                                ...              2
# 13                                                ...              2
# 64                                                ...              2
# 14                                                ...              2
# 65                                                ...              2
# 66                                                ...              2
# 15                                                ...              2
# 71                                                ...              2
# 20                                                ...              2
# 21                                                ...              2
# 72                                                ...              2
# 75                                                ...              2
# 24                                                ...              2
# 28                                                ...              2
# 79                                                ...              2
# 32                                                ...              2
# 83                                                ...              2
# 30                                                ...              2
# 81                                                ...              2
# 82                                                ...              2
# 31                                                ...              2
# 89                                                ...              2
# 38                                                ...              2
# 90                                                ...              2
# 39                                                ...              2
# 91                                                ...              2
# 40                                                ...              2
# 96                                                ...              2
# 45                                                ...              2
# 46                                                ...              2
# 97                                                ...              2

# %%
document_df[ document_df['cluster_label']==3 ].sort_values(by='filename')
# Out:
#                           filename  \
# 6        comfort_honda_accord_2008
# 57       comfort_honda_accord_2008
# 7        comfort_toyota_camry_2007
# 58       comfort_toyota_camry_2007
# 16   gas_mileage_toyota_camry_2007
# 67   gas_mileage_toyota_camry_2007
# 17      interior_honda_accord_2008
# 68      interior_honda_accord_2008
# 18      interior_toyota_camry_2007
# 69      interior_toyota_camry_2007
# 22       mileage_honda_accord_2008
# 73       mileage_honda_accord_2008
# 25   performance_honda_accord_2008
# 76   performance_honda_accord_2008
# 80       quality_toyota_camry_2007
# 29       quality_toyota_camry_2007
# 88         seats_honda_accord_2008
# 37         seats_honda_accord_2008
# 47  transmission_toyota_camry_2007
# 98  transmission_toyota_camry_2007
#
#                                          opinion_text  cluster_label
# 6                                                 ...              3
# 57                                                ...              3
# 7                                                 ...              3
# 58                                                ...              3
# 16                                                ...              3
# 67                                                ...              3
# 17                                                ...              3
# 68                                                ...              3
# 18                                                ...              3
# 69                                                ...              3
# 22                                                ...              3
# 73                                                ...              3
# 25                                                ...              3
# 76                                                ...              3
# 80                                                ...              3
# 29                                                ...              3
# 88                                                ...              3
# 37                                                ...              3
# 47                                                ...              3
# 98                                                ...              3

# %%
document_df[ document_df['cluster_label']==4 ].sort_values(by='filename')
# Out:
#                         filename  \
# 2     battery-life_amazon_kindle
# 53    battery-life_amazon_kindle
# 3     battery-life_ipod_nano_8gb
# 54    battery-life_ipod_nano_8gb
# 4    battery-life_netbook_1005ha
# 55   battery-life_netbook_1005ha
# 19       keyboard_netbook_1005ha
# 70       keyboard_netbook_1005ha
# 26    performance_netbook_1005ha
# 77    performance_netbook_1005ha
# 35          screen_ipod_nano_8gb
# 86          screen_ipod_nano_8gb
# 36         screen_netbook_1005ha
# 87         screen_netbook_1005ha
# 92      size_asus_netbook_1005ha
# 41      size_asus_netbook_1005ha
# 93           sound_ipod_nano_8gb
# 42           sound_ipod_nano_8gb
# 49           video_ipod_nano_8gb
# 100          video_ipod_nano_8gb
#
#                                           opinion_text  cluster_label
# 2                                                  ...              4
# 53                                                 ...              4
# 3                                                  ...              4
# 54                                                 ...              4
# 4                                                  ...              4
# 55                                                 ...              4
# 19                                                 ...              4
# 70                                                 ...              4
# 26                                                 ...              4
# 77                                                 ...              4
# 35                                                 ...              4
# 86                                                 ...              4
# 36                                                 ...              4
# 87                                                 ...              4
# 92                                                 ...              4
# 41                                                 ...              4
# 93       headphone jack i got a clear case for it a...              4
# 42       headphone jack i got a clear case for it a...              4
# 49                                                 ...              4
# 100                                                ...              4

# %%
# 3개의 집합으로 군집화
km_cluster = KMeans(n_clusters=3, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_
# 소속 클러스트를 cluster_label 컬럼으로 할당하고 cluster_label 값으로 정렬
document_df['cluster_label'] = cluster_label

# %%
document_df[ document_df['cluster_label']==0 ].sort_values(by='filename')
# Out:
#                             filename  \
# 0      accuracy_garmin_nuvi_255W_gps
# 51     accuracy_garmin_nuvi_255W_gps
# 53        battery-life_amazon_kindle
# 2         battery-life_amazon_kindle
# 3         battery-life_ipod_nano_8gb
# 54        battery-life_ipod_nano_8gb
# 4        battery-life_netbook_1005ha
# 55       battery-life_netbook_1005ha
# 5              buttons_amazon_kindle
# 56             buttons_amazon_kindle
# 8    directions_garmin_nuvi_255W_gps
# 59   directions_garmin_nuvi_255W_gps
# 9       display_garmin_nuvi_255W_gps
# 60      display_garmin_nuvi_255W_gps
# 10     eyesight-issues_amazon_kindle
# 61     eyesight-issues_amazon_kindle
# 62                 features_windows7
# 11                 features_windows7
# 63               fonts_amazon_kindle
# 12               fonts_amazon_kindle
# 70           keyboard_netbook_1005ha
# 19           keyboard_netbook_1005ha
# 74          navigation_amazon_kindle
# 23          navigation_amazon_kindle
# 77        performance_netbook_1005ha
# 26        performance_netbook_1005ha
# 78               price_amazon_kindle
# 27               price_amazon_kindle
# 33    satellite_garmin_nuvi_255W_gps
# 84    satellite_garmin_nuvi_255W_gps
# 85       screen_garmin_nuvi_255W_gps
# 34       screen_garmin_nuvi_255W_gps
# 86              screen_ipod_nano_8gb
# 35              screen_ipod_nano_8gb
# 87             screen_netbook_1005ha
# 36             screen_netbook_1005ha
# 92          size_asus_netbook_1005ha
# 41          size_asus_netbook_1005ha
# 42               sound_ipod_nano_8gb
# 93               sound_ipod_nano_8gb
# 94        speed_garmin_nuvi_255W_gps
# 43        speed_garmin_nuvi_255W_gps
# 95                    speed_windows7
# 44                    speed_windows7
# 99      updates_garmin_nuvi_255W_gps
# 48      updates_garmin_nuvi_255W_gps
# 100              video_ipod_nano_8gb
# 49               video_ipod_nano_8gb
# 50        voice_garmin_nuvi_255W_gps
# 101       voice_garmin_nuvi_255W_gps
#
#                                           opinion_text  cluster_label
# 0                                                  ...              0
# 51                                                 ...              0
# 53                                                 ...              0
# 2                                                  ...              0
# 3                                                  ...              0
# 54                                                 ...              0
# 4                                                  ...              0
# 55                                                 ...              0
# 5                                                  ...              0
# 56                                                 ...              0
# 8                                                  ...              0
# 59                                                 ...              0
# 9                                                  ...              0
# 60                                                 ...              0
# 10                                                 ...              0
# 61                                                 ...              0
# 62                                                 ...              0
# 11                                                 ...              0
# 63                                                 ...              0
# 12                                                 ...              0
# 70                                                 ...              0
# 19                                                 ...              0
# 74                                                 ...              0
# 23                                                 ...              0
# 77                                                 ...              0
# 26                                                 ...              0
# 78                                                 ...              0
# 27                                                 ...              0
# 33                                                 ...              0
# 84                                                 ...              0
# 85                                                 ...              0
# 34                                                 ...              0
# 86                                                 ...              0
# 35                                                 ...              0
# 87                                                 ...              0
# 36                                                 ...              0
# 92                                                 ...              0
# 41                                                 ...              0
# 42       headphone jack i got a clear case for it a...              0
# 93       headphone jack i got a clear case for it a...              0
# 94                                                 ...              0
# 43                                                 ...              0
# 95                                                 ...              0
# 44                                                 ...              0
# 99                                                 ...              0
# 48                                                 ...              0
# 100                                                ...              0
# 49                                                 ...              0
# 50                                                 ...              0
# 101                                                ...              0

# %% [markdown]
# * KMeans 객체의 cluster_centers_ 속성은 개별 피처들의 클러스터 중심과의 상대 위치를 정규화한 숫자값들입니다
# * 0~1까지ㅣ의 값으로 표현되며 1에 가까울수록 중심에 더 가깝다는 의미입니다

# %%
cluster_centers = km_cluster.cluster_centers_
print('cluster_centers shape :', cluster_centers.shape)
print(cluster_centers)
# Out:
# cluster_centers shape : (3, 4611)
# [[0.01005141 0.         0.         ... 0.00712732 0.         0.        ]
#  [0.         0.00094399 0.         ... 0.         0.         0.        ]
#  [0.         0.00101894 0.0017818  ... 0.         0.00187208 0.00147903]]

# %% [markdown]
# ## 군집별 top n 핵심단어, 대상 파일명 등

# %%
feature_names = tfidf_vect.get_feature_names()
# print(feature_names)
cluster_details={}

# %%
# cluster_centers를 정렬 - 정렬 결과의 index 값을 얻기 위해서 argsort 실행(내림차순)
centoid_feature_ordered_ind = km_cluster.cluster_centers_.argsort()[:,::-1]

# %%
# 개별 군집별로 iteration하면서 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명 출력
# cluster_details에 입력
for cluster_num in range(3):
    # 개별 군집별 정보를 담을 데이터 초기화
    cluster_details[cluster_num] = {}
    cluster_details[cluster_num]['cluster'] = cluster_num
    # cluster_centers_.argsort()[:,::-1]로 얻은 index를 이용하여 top n
    # 피처 단어들의 인덱스, 각 클러스터 별 10개의 인덱스
    top_feature_indexes = centoid_feature_ordered_ind[cluster_num, :10]
    # 추출한 인덱스로 단어 추출
    top_features = [ feature_names[ind] for ind in top_feature_indexes ]
    # 단어들의 상대적 거리 추출
    top_feature_values\
    = km_cluster.cluster_centers_[ cluster_num, top_feature_indexes].tolist()
    
    # cluster_details 딕셔너리 객체에 개별 군집별 핵심 단어와 중심위치 상대값,
    # 그리고 해당 파일명 저장
    cluster_details[cluster_num]['top_features'] = top_features
    cluster_details[cluster_num]['top_feature_value'] = top_feature_values
    filenames = document_df[ document_df['cluster_label'] == cluster_num]['filename']
    filenames = filenames.values.tolist()
    cluster_details[cluster_num]['filenames'] = filenames
    
# 완성된 자료 출력
for cluster_num, cluster_detail in cluster_details.items():
    print('###### Clsuter {0}'.format(cluster_num))
    print('Top features:', cluster_detail['top_features']) # 군집에 가까운 핵심단어
    print('Reviews 파일명 : ', cluster_detail['filenames'][:7]) # 핵심파일 7개
    print('==================================================')
# Out:
# ###### Clsuter 0
# Top features: ['screen', 'battery', 'keyboard', 'battery life', 'life', 'kindle', 'video', 'direction', 'voice', 'size']
# Reviews 파일명 :  ['accuracy_garmin_nuvi_255W_gps', 'battery-life_amazon_kindle', 'battery-life_ipod_nano_8gb', 'battery-life_netbook_1005ha', 'buttons_amazon_kindle', 'directions_garmin_nuvi_255W_gps', 'display_garmin_nuvi_255W_gps']
# ==================================================
# ###### Clsuter 1
# Top features: ['interior', 'seat', 'mileage', 'comfortable', 'gas', 'gas mileage', 'transmission', 'car', 'performance', 'quality']
# Reviews 파일명 :  ['comfort_honda_accord_2008', 'comfort_toyota_camry_2007', 'gas_mileage_toyota_camry_2007', 'interior_honda_accord_2008', 'interior_toyota_camry_2007', 'mileage_honda_accord_2008', 'performance_honda_accord_2008']
# ==================================================
# ###### Clsuter 2
# Top features: ['room', 'hotel', 'service', 'staff', 'food', 'location', 'bathroom', 'clean', 'price', 'parking']
# Reviews 파일명 :  ['bathroom_bestwestern_hotel_sfo', 'food_holiday_inn_london', 'food_swissotel_chicago', 'free_bestwestern_hotel_sfo', 'location_bestwestern_hotel_sfo', 'location_holiday_inn_london', 'parking_bestwestern_hotel_sfo']
# ==================================================
